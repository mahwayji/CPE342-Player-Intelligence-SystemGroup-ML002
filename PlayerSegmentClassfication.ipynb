# %% [markdown]
# # Task 2: Player Segment Classification

# %% [markdown]
# In this task we will have to classified which segment of the user are which are: Casual player, Competitive grinder, Social player, and Whale. We will be using Multi-class classification for as a method for this task.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Step 1: Data Preparation

# %% [markdown]
# ### Step 1.1: Dowload Data

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#          id player_id  play_frequency  avg_session_duration  \
# 0  PLY00001   P050236        5.495437             24.837349
# 1  PLY00002   P108696        9.991089             88.376322
# 2  PLY00003   P113532       14.234225            101.712292
# 3  PLY00004   P123930        3.373683            191.975841
# 4  PLY00005   P068623       22.469353             28.042509
#
#    total_playtime_hours  login_streak  days_since_last_login  \
# 0           2740.945124          60.0              56.034052
# 1                   NaN          22.0              75.036888
# 2           2828.479467          66.0                    NaN
# 3           1915.082950          80.0               0.127910
# 4            517.921948           NaN              45.078460
#
#    total_spending_thb  avg_monthly_spending  spending_frequency  ...  \
# 0        58219.915660            434.038311           17.790970  ...
# 1        28966.163953           4233.532935           28.862134  ...
# 2        44478.823835           4849.491895           22.536406  ...
# 3        57074.116993           6863.516123           10.565666  ...
# 4                 NaN           4408.101247           11.226504  ...
#
#    platform  device_type  payment_method  language  account_status  \
# 0        PC        Phone          Wallet        DE          Active
# 1   Console      Desktop            Card        ES         Dormant
# 2        PC       Laptop             NaN        EN         Dormant
# 3   Console       Tablet             NaN        ES         Dormant
# 4        PC       Tablet            Gift        EN          Active
#
#    player_type_tag  engagement_level  loyalty_tier  skill_tier  segment
# 0           Social               Low        Silver         NaN        0
# 1        Collector               Low      Platinum        Gold        2
# 2           Casual              High       Diamond        Gold        3
# 3      Competitive           Veteran        Silver        Gold        3
# 4           Casual               Mid        Silver         NaN        1
#
# [5 rows x 47 columns]

# %%
df.describe().T
# Out:
#                                      count          mean           std  \
# play_frequency                     93785.0     12.162113      7.112615
# avg_session_duration               93771.0    107.922960     54.461009
# total_playtime_hours               93887.0   1706.987371    939.497982
# login_streak                       93938.0     55.095968     35.385126
# days_since_last_login              93878.0     45.917386     20.763590
# total_spending_thb                 93902.0  34156.914790  22008.333299
# avg_monthly_spending               93923.0   3304.075003   1929.848230
# spending_frequency                 93898.0     17.000950      9.602913
# friend_count                       93720.0    107.292168     65.017491
# team_play_percentage               93963.0     50.226549     19.707257
# chat_activity_score                93893.0     67.515136     43.562074
# friend_invites_sent                93823.0     43.221438     27.115444
# gifts_sent_received                93938.0     86.758383     54.345783
# ranked_participation_rate          93833.0     49.953316     27.411895
# tournament_entries                 93804.0     27.237815     17.687710
# competitive_rank                   93863.0      4.538157      2.418260
# win_rate_ranked                    93830.0     50.347402     10.057405
# watches_esports                    93776.0      0.402896      0.490483
# achievement_completion_rate        93764.0     50.255567     19.485132
# collection_progress                93744.0     50.348058     19.402525
# rare_items_count                   93964.0     86.837172     55.218191
# speed_of_progression               93831.0      5.565904      3.547631
# item_type_preference_cosmetic      93900.0      0.599646      0.193357
# item_type_preference_performance   93824.0      0.599521      0.192830
# item_type_preference_social        93756.0      0.500765      0.195423
# account_age_days                   93812.0    822.401377    461.302489
# vip_tier                           93882.0      1.297991      1.412312
# responds_to_discounts              93769.0      0.601819      0.489526
# preferred_game_mode                93968.0      1.994328      1.411464
# avg_match_length                   93805.0     35.037961     14.724860
# peak_concurrent_hours              94023.0     55.715694     35.297009
# random_metric_1                    93842.0    498.223300    288.331613
# random_metric_2                    93907.0      0.500032      0.288996
# random_metric_3                    93881.0     99.486957     49.946989
# segment                           101658.0      1.115889      1.094777
#
#                                            min           25%           50%  \
# play_frequency                    1.000033e+00      6.437830     11.449866
# avg_session_duration              2.000584e+01     64.559580    103.028355
# total_playtime_hours              1.000188e+02    973.768239   1645.831217
# login_streak                      0.000000e+00     27.000000     52.000000
# days_since_last_login             6.466683e-03     31.260410     45.724496
# total_spending_thb                5.003089e+02  16368.741422  31528.039053
# avg_monthly_spending              1.000826e+02   1780.923045   3160.767590
# spending_frequency                1.000775e+00      9.445409     16.251247
# friend_count                      0.000000e+00     56.000000    103.000000
# team_play_percentage              5.000000e+00     36.615032     50.172440
# chat_activity_score               1.852541e-03     32.311508     62.764487
# friend_invites_sent               0.000000e+00     22.000000     41.000000
# gifts_sent_received               0.000000e+00     43.000000     82.000000
# ranked_participation_rate         0.000000e+00     29.747045     50.001619
# tournament_entries                0.000000e+00     13.000000     25.000000
# competitive_rank                  0.000000e+00      3.000000      5.000000
# win_rate_ranked                   2.500000e+01     43.430765     50.379696
# watches_esports                   0.000000e+00      0.000000      0.000000
# achievement_completion_rate       1.000000e+01     36.557832     50.200473
# collection_progress               1.000000e+01     36.733158     50.282959
# rare_items_count                  0.000000e+00     43.000000     81.000000
# speed_of_progression              4.178204e-04      2.702668      5.217316
# item_type_preference_cosmetic     5.000000e-02      0.467272      0.603011
# item_type_preference_performance  5.000000e-02      0.468070      0.602243
# item_type_preference_social       5.000000e-02      0.366827      0.501024
# account_age_days                  0.000000e+00    470.000000    800.000000
# vip_tier                          0.000000e+00      0.000000      1.000000
# responds_to_discounts             0.000000e+00      0.000000      1.000000
# preferred_game_mode               0.000000e+00      1.000000      2.000000
# avg_match_length                  3.077099e-04     24.868829     34.952427
# peak_concurrent_hours             2.781706e-03     27.353325     52.243561
# random_metric_1                   3.382183e-03    248.167941    497.985340
# random_metric_2                   8.281503e-07      0.251236      0.499016
# random_metric_3                  -1.220000e+02     66.000000     99.000000
# segment                           0.000000e+00      0.000000      1.000000
#
#                                            75%            max
# play_frequency                       16.918216      50.186794
# avg_session_duration                144.677928     394.900718
# total_playtime_hours               2345.518903    6266.515056
# login_streak                         79.000000     234.000000
# days_since_last_login                60.184174     130.071576
# total_spending_thb                48827.625917  148349.870989
# avg_monthly_spending               4611.562739   12637.762963
# spending_frequency                   23.484908      60.936367
# friend_count                        151.000000     410.000000
# team_play_percentage                 63.661491     100.000000
# chat_activity_score                  96.934454     266.025304
# friend_invites_sent                  62.000000     167.000000
# gifts_sent_received                 123.000000     340.000000
# ranked_participation_rate            70.140137     100.000000
# tournament_entries                   39.000000     115.000000
# competitive_rank                      6.000000      10.000000
# win_rate_ranked                      57.213320      75.000000
# watches_esports                       1.000000       1.000000
# achievement_completion_rate          63.756854      95.000000
# collection_progress                  63.819338      95.000000
# rare_items_count                    124.000000     364.000000
# speed_of_progression                  7.946090      23.366394
# item_type_preference_cosmetic         0.738546       0.950000
# item_type_preference_performance      0.737533       0.950000
# item_type_preference_social           0.634404       0.950000
# account_age_days                   1136.000000    2946.000000
# vip_tier                              2.000000       5.000000
# responds_to_discounts                 1.000000       1.000000
# preferred_game_mode                   3.000000       4.000000
# avg_match_length                     45.006767      97.208024
# peak_concurrent_hours                79.322472     217.732257
# random_metric_1                     746.667138     999.989985
# random_metric_2                       0.751149       0.999992
# random_metric_3                     133.000000     334.000000
# segment                               2.000000       3.000000

# %%
df['segment'].value_counts()
# Out:
# segment
# 0    40064
# 1    25397
# 2    20549
# 3    15648
# Name: count, dtype: int64

# %% [markdown]
# ### Task 1.2: Missing Value

# %%
def create_null_table(df):
    null_count = df.isnull().sum()
    null_percentage = df.isnull().sum() * 100 / len(df)

    # Create table
    null_table = pd.concat([null_count, null_percentage] ,axis = 1)

    # Rename columns
    null_table = null_table.rename(columns={0: "Missing value counts", 1: "Missing value percentage"})

    # Sort value
    null_table = null_table[null_table.iloc[:,-1] != 0].sort_values('Missing value counts', ascending=False).round(1)
    return null_table

# %% [markdown]
# #### Step 1.2.1: Numerical Data

# %%
df_num = df.select_dtypes('number')

df_num.columns
# Out:
# Index(['play_frequency', 'avg_session_duration', 'total_playtime_hours',
#        'login_streak', 'days_since_last_login', 'total_spending_thb',
#        'avg_monthly_spending', 'spending_frequency', 'friend_count',
#        'team_play_percentage', 'chat_activity_score', 'friend_invites_sent',
#        'gifts_sent_received', 'ranked_participation_rate',
#        'tournament_entries', 'competitive_rank', 'win_rate_ranked',
#        'watches_esports', 'achievement_completion_rate', 'collection_progress',
#        'rare_items_count', 'speed_of_progression',
#        'item_type_preference_cosmetic', 'item_type_preference_performance',
#        'item_type_preference_social', 'account_age_days', 'vip_tier',
#        'responds_to_discounts', 'preferred_game_mode', 'avg_match_length',
#        'peak_concurrent_hours', 'random_metric_1', 'random_metric_2',
#        'random_metric_3', 'segment'],
#       dtype='object')

# %%
num_null = create_null_table(df_num)

num_null
# Out:
#                                   Missing value counts  \
# friend_count                                      7938
# collection_progress                               7914
# item_type_preference_social                       7902
# achievement_completion_rate                       7894
# responds_to_discounts                             7889
# avg_session_duration                              7887
# watches_esports                                   7882
# play_frequency                                    7873
# tournament_entries                                7854
# avg_match_length                                  7853
# account_age_days                                  7846
# friend_invites_sent                               7835
# item_type_preference_performance                  7834
# win_rate_ranked                                   7828
# speed_of_progression                              7827
# ranked_participation_rate                         7825
# random_metric_1                                   7816
# competitive_rank                                  7795
# days_since_last_login                             7780
# random_metric_3                                   7777
# vip_tier                                          7776
# total_playtime_hours                              7771
# chat_activity_score                               7765
# spending_frequency                                7760
# item_type_preference_cosmetic                     7758
# total_spending_thb                                7756
# random_metric_2                                   7751
# avg_monthly_spending                              7735
# login_streak                                      7720
# gifts_sent_received                               7720
# team_play_percentage                              7695
# rare_items_count                                  7694
# preferred_game_mode                               7690
# peak_concurrent_hours                             7635
#
#                                   Missing value percentage
# friend_count                                           7.8
# collection_progress                                    7.8
# item_type_preference_social                            7.8
# achievement_completion_rate                            7.8
# responds_to_discounts                                  7.8
# avg_session_duration                                   7.8
# watches_esports                                        7.8
# play_frequency                                         7.7
# tournament_entries                                     7.7
# avg_match_length                                       7.7
# account_age_days                                       7.7
# friend_invites_sent                                    7.7
# item_type_preference_performance                       7.7
# win_rate_ranked                                        7.7
# speed_of_progression                                   7.7
# ranked_participation_rate                              7.7
# random_metric_1                                        7.7
# competitive_rank                                       7.7
# days_since_last_login                                  7.7
# random_metric_3                                        7.7
# vip_tier                                               7.6
# total_playtime_hours                                   7.6
# chat_activity_score                                    7.6
# spending_frequency                                     7.6
# item_type_preference_cosmetic                          7.6
# total_spending_thb                                     7.6
# random_metric_2                                        7.6
# avg_monthly_spending                                   7.6
# login_streak                                           7.6
# gifts_sent_received                                    7.6
# team_play_percentage                                   7.6
# rare_items_count                                       7.6
# preferred_game_mode                                    7.6
# peak_concurrent_hours                                  7.5

# %% [markdown]
# Since the number of null value are really close for each columns, we would like to check whether it is related to each other.

# %%
df_num_drop = df_num.dropna(subset = ['peak_concurrent_hours'], how = 'any')

create_null_table(df_num_drop)
# Out:
#                                   Missing value counts  \
# collection_progress                               7340
# friend_count                                      7327
# play_frequency                                    7307
# win_rate_ranked                                   7301
# item_type_preference_social                       7300
# avg_match_length                                  7293
# responds_to_discounts                             7292
# achievement_completion_rate                       7288
# watches_esports                                   7286
# avg_session_duration                              7282
# account_age_days                                  7268
# tournament_entries                                7250
# item_type_preference_performance                  7247
# speed_of_progression                              7245
# friend_invites_sent                               7235
# competitive_rank                                  7231
# ranked_participation_rate                         7229
# days_since_last_login                             7215
# chat_activity_score                               7215
# vip_tier                                          7208
# item_type_preference_cosmetic                     7204
# random_metric_3                                   7194
# random_metric_1                                   7193
# spending_frequency                                7172
# total_playtime_hours                              7163
# random_metric_2                                   7161
# total_spending_thb                                7152
# login_streak                                      7147
# avg_monthly_spending                              7143
# rare_items_count                                  7137
# gifts_sent_received                               7127
# team_play_percentage                              7095
# preferred_game_mode                               7095
#
#                                   Missing value percentage
# collection_progress                                    7.8
# friend_count                                           7.8
# play_frequency                                         7.8
# win_rate_ranked                                        7.8
# item_type_preference_social                            7.8
# avg_match_length                                       7.8
# responds_to_discounts                                  7.8
# achievement_completion_rate                            7.8
# watches_esports                                        7.7
# avg_session_duration                                   7.7
# account_age_days                                       7.7
# tournament_entries                                     7.7
# item_type_preference_performance                       7.7
# speed_of_progression                                   7.7
# friend_invites_sent                                    7.7
# competitive_rank                                       7.7
# ranked_participation_rate                              7.7
# days_since_last_login                                  7.7
# chat_activity_score                                    7.7
# vip_tier                                               7.7
# item_type_preference_cosmetic                          7.7
# random_metric_3                                        7.7
# random_metric_1                                        7.7
# spending_frequency                                     7.6
# total_playtime_hours                                   7.6
# random_metric_2                                        7.6
# total_spending_thb                                     7.6
# login_streak                                           7.6
# avg_monthly_spending                                   7.6
# rare_items_count                                       7.6
# gifts_sent_received                                    7.6
# team_play_percentage                                   7.5
# preferred_game_mode                                    7.5

# %% [markdown]
# The result sadly is *no*, so we have to approach with other method instead.

# %% [markdown]
# ##### Replace the missing value

# %% [markdown]
# After observing we found that the minimum value of total spending is not 0, we diagnose that the data might store as null for the non spending value. The catch is that some rows having the total spending as null but they have the spending frequency and/or the average monthly spending value that is not 0. So, we have to carefully filled the value with the specific condition

# %%
df_mice = df_num.copy(deep=True)

mice_imputer = IterativeImputer()

df_mice = mice_imputer.fit_transform(df_mice)

# %%
df_num_filled = pd.DataFrame(df_mice, columns = df_num.columns)

df_num_filled
# Out:
#         play_frequency  avg_session_duration  total_playtime_hours  \
# 0             5.495437             24.837349           2740.945124
# 1             9.991089             88.376322           1643.677401
# 2            14.234225            101.712292           2828.479467
# 3             3.373683            191.975841           1915.082950
# 4            22.469353             28.042509            517.921948
# ...                ...                   ...                   ...
# 101653       17.189970            125.413304           4042.198275
# 101654        7.560260            120.962552           1799.108384
# 101655       11.765396             38.541917           1097.814242
# 101656       12.898003             64.701401           3563.506452
# 101657       15.265967            130.211828            624.018328
#
#         login_streak  days_since_last_login  total_spending_thb  \
# 0          60.000000              56.034052        58219.915660
# 1          22.000000              75.036888        28966.163953
# 2          66.000000              40.142612        44478.823835
# 3          80.000000               0.127910        57074.116993
# 4          54.708112              45.078460        33249.740245
# ...              ...                    ...                 ...
# 101653     47.000000              42.264454        30455.881472
# 101654     20.000000              27.647682        29782.184066
# 101655     25.000000              47.259330        39479.658717
# 101656    120.000000               6.810932        48523.945493
# 101657     58.000000               0.185670        48073.883470
#
#         avg_monthly_spending  spending_frequency  friend_count  \
# 0                 434.038311           17.790970          58.0
# 1                4233.532935           28.862134         276.0
# 2                4849.491895           22.536406          71.0
# 3                6863.516123           10.565666         105.0
# 4                4408.101247           11.226504         111.0
# ...                      ...                 ...           ...
# 101653           5058.189653            9.852469         179.0
# 101654           1516.687257            8.235531          52.0
# 101655           3147.264423            9.703321         149.0
# 101656           1596.091703           31.721567         193.0
# 101657           7415.983681           27.716821          90.0
#
#         team_play_percentage  ...  account_age_days  vip_tier  \
# 0                  47.791178  ...             503.0  0.000000
# 1                  52.789877  ...             500.0  3.000000
# 2                  58.267306  ...            1390.0  3.000000
# 3                  67.274038  ...            1123.0  3.000000
# 4                  50.677100  ...             580.0  2.000000
# ...                      ...  ...               ...       ...
# 101653             11.689707  ...            1056.0  1.000000
# 101654              5.000000  ...             956.0  1.000000
# 101655             44.062523  ...             458.0  1.725121
# 101656             59.351458  ...            1544.0  3.000000
# 101657             32.047768  ...             908.0  1.000000
#
#         responds_to_discounts  preferred_game_mode  avg_match_length  \
# 0                    1.000000             1.991093         39.255174
# 1                    0.000000             0.000000         60.140761
# 2                    0.597961             0.000000         26.718983
# 3                    1.000000             2.000000         13.432821
# 4                    0.604532             1.966787         35.063033
# ...                       ...                  ...               ...
# 101653               0.000000             4.000000         41.244437
# 101654               0.000000             4.000000         29.802865
# 101655               1.000000             3.000000         23.665582
# 101656               0.000000             4.000000         32.225452
# 101657               0.000000             3.000000         15.982590
#
#         peak_concurrent_hours  random_metric_1  random_metric_2  \
# 0                   22.813403       466.695020         0.498406
# 1                   25.409615       989.393688         0.089247
# 2                   59.151505       433.199081         0.261515
# 3                   47.247822       827.771953         0.604005
# 4                   47.015102        32.321928         0.350878
# ...                       ...              ...              ...
# 101653              96.660119        26.216671         0.249959
# 101654              35.052080       325.197382         0.293512
# 101655              19.805852       567.579047         0.503611
# 101656              38.011697       396.194705         0.505487
# 101657             140.543617       287.021936         0.394286
#
#         random_metric_3  segment
# 0                 139.0      0.0
# 1                 136.0      2.0
# 2                  38.0      3.0
# 3                  49.0      3.0
# 4                 167.0      1.0
# ...                 ...      ...
# 101653            119.0      1.0
# 101654            118.0      0.0
# 101655            149.0      2.0
# 101656            226.0      3.0
# 101657             65.0      3.0
#
# [101658 rows x 35 columns]

# %% [markdown]
# #### Step 1.2.2: Categorical Data

# %%
df_cat = df.select_dtypes('object')

df_cat.columns
# Out:
# Index(['id', 'player_id', 'region', 'platform', 'device_type',
#        'payment_method', 'language', 'account_status', 'player_type_tag',
#        'engagement_level', 'loyalty_tier', 'skill_tier'],
#       dtype='object')

# %% [markdown]
# Drop insignificant columns

# %%
df_cat.drop(columns = ['id', 'player_id'], inplace = True)

df_cat.columns
# Out:
# Index(['region', 'platform', 'device_type', 'payment_method', 'language',
#        'account_status', 'player_type_tag', 'engagement_level', 'loyalty_tier',
#        'skill_tier'],
#       dtype='object')

# %% [markdown]
# Check the null values

# %%
null_cat = create_null_table(df_cat)

null_cat
# Out:
#                   Missing value counts  Missing value percentage
# payment_method                   31145                      30.6
# region                           26535                      26.1
# engagement_level                  7962                       7.8
# player_type_tag                   7920                       7.8
# language                          7898                       7.8
# skill_tier                        7862                       7.7
# device_type                       7814                       7.7
# loyalty_tier                      7737                       7.6
# account_status                    7717                       7.6
# platform                          7681                       7.6

# %% [markdown]
# The percentage of missing value of *payment method* and *region* are huge, and we think this might be significant. So, we will try to use this as an information too.

# %%
def showRatio(df, column):
    count = dict(df[column].value_counts())
    count['null'] = df[column].isnull().sum()
    plt.bar(x=count.keys(), height = count.values())

# %%
showRatio(df, 'payment_method')

# %% [markdown]
# Create new columns to store if payment is null, and filled the old one with 'ffill'

# %%
df_cat['null_payment'] = [1.0 if i else 0.0 for i in df['payment_method'].isnull()]

df_cat['payment_method'].ffill(inplace = True)
df_cat
# Out:
# /tmp/ipython-input-1449522351.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cat['payment_method'].ffill(inplace = True)
#        region platform device_type payment_method language account_status  \
# 0       LATAM       PC       Phone         Wallet       DE         Active
# 1         NaN  Console     Desktop           Card       ES        Dormant
# 2         NaN       PC      Laptop           Card       EN        Dormant
# 3         NaN  Console      Tablet           Card       ES        Dormant
# 4         NaN       PC      Tablet           Gift       EN         Active
# ...       ...      ...         ...            ...      ...            ...
# 101653   APAC  Console      Tablet           Card       KR         Active
# 101654     EU  Console       Phone           Card       DE            NaN
# 101655  LATAM  Console      Tablet           Gift       ES            NaN
# 101656  LATAM  Console     Desktop           Card       ES         Active
# 101657    NaN  Console     Desktop           Card       KR        Dormant
#
#        player_type_tag engagement_level loyalty_tier skill_tier  null_payment
# 0               Social              Low       Silver        NaN           0.0
# 1            Collector              Low     Platinum       Gold           0.0
# 2               Casual             High      Diamond       Gold           1.0
# 3          Competitive          Veteran       Silver       Gold           1.0
# 4               Casual              Mid       Silver        NaN           0.0
# ...                ...              ...          ...        ...           ...
# 101653          Social             High       Bronze     Bronze           0.0
# 101654          Casual              Low          NaN    Diamond           1.0
# 101655          Social             High       Silver        NaN           0.0
# 101656     Competitive              Mid         Gold     Bronze           0.0
# 101657       Collector              Mid         Gold    Diamond           1.0
#
# [101658 rows x 11 columns]

# %%
df_cat['payment_method'].isnull().sum()
# Out:
# np.int64(0)

# %%
showRatio(df_cat, 'region')

# %%
df_cat['null_region'] = [1.0 if i else 0.0 for i in df['region'].isnull()]

df_cat['region'].ffill(inplace = True)
df_cat
# Out:
# /tmp/ipython-input-1419082225.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cat['region'].ffill(inplace = True)
#        region platform device_type payment_method language account_status  \
# 0       LATAM       PC       Phone         Wallet       DE         Active
# 1       LATAM  Console     Desktop           Card       ES        Dormant
# 2       LATAM       PC      Laptop           Card       EN        Dormant
# 3       LATAM  Console      Tablet           Card       ES        Dormant
# 4       LATAM       PC      Tablet           Gift       EN         Active
# ...       ...      ...         ...            ...      ...            ...
# 101653   APAC  Console      Tablet           Card       KR         Active
# 101654     EU  Console       Phone           Card       DE            NaN
# 101655  LATAM  Console      Tablet           Gift       ES            NaN
# 101656  LATAM  Console     Desktop           Card       ES         Active
# 101657  LATAM  Console     Desktop           Card       KR        Dormant
#
#        player_type_tag engagement_level loyalty_tier skill_tier  null_payment  \
# 0               Social              Low       Silver        NaN           0.0
# 1            Collector              Low     Platinum       Gold           0.0
# 2               Casual             High      Diamond       Gold           1.0
# 3          Competitive          Veteran       Silver       Gold           1.0
# 4               Casual              Mid       Silver        NaN           0.0
# ...                ...              ...          ...        ...           ...
# 101653          Social             High       Bronze     Bronze           0.0
# 101654          Casual              Low          NaN    Diamond           1.0
# 101655          Social             High       Silver        NaN           0.0
# 101656     Competitive              Mid         Gold     Bronze           0.0
# 101657       Collector              Mid         Gold    Diamond           1.0
#
#         null_region
# 0               0.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 101653          0.0
# 101654          0.0
# 101655          0.0
# 101656          0.0
# 101657          1.0
#
# [101658 rows x 12 columns]

# %% [markdown]
# At the moment we will assume that the data have normal distributed, and we will replace the null value for each remaining columns as the mode of it.

# %%
remain_cat = create_null_table(df_cat)

remain_cat
# Out:
#                   Missing value counts  Missing value percentage
# engagement_level                  7962                       7.8
# player_type_tag                   7920                       7.8
# language                          7898                       7.8
# skill_tier                        7862                       7.7
# device_type                       7814                       7.7
# loyalty_tier                      7737                       7.6
# account_status                    7717                       7.6
# platform                          7681                       7.6

# %%
for i in remain_cat.index:
    df_cat.fillna({i: df_cat[i].mode()[0]}, inplace = True)

df_cat
# Out:
#        region platform device_type payment_method language account_status  \
# 0       LATAM       PC       Phone         Wallet       DE         Active
# 1       LATAM  Console     Desktop           Card       ES        Dormant
# 2       LATAM       PC      Laptop           Card       EN        Dormant
# 3       LATAM  Console      Tablet           Card       ES        Dormant
# 4       LATAM       PC      Tablet           Gift       EN         Active
# ...       ...      ...         ...            ...      ...            ...
# 101653   APAC  Console      Tablet           Card       KR         Active
# 101654     EU  Console       Phone           Card       DE         Active
# 101655  LATAM  Console      Tablet           Gift       ES         Active
# 101656  LATAM  Console     Desktop           Card       ES         Active
# 101657  LATAM  Console     Desktop           Card       KR        Dormant
#
#        player_type_tag engagement_level loyalty_tier skill_tier  null_payment  \
# 0               Social              Low       Silver     Bronze           0.0
# 1            Collector              Low     Platinum       Gold           0.0
# 2               Casual             High      Diamond       Gold           1.0
# 3          Competitive          Veteran       Silver       Gold           1.0
# 4               Casual              Mid       Silver     Bronze           0.0
# ...                ...              ...          ...        ...           ...
# 101653          Social             High       Bronze     Bronze           0.0
# 101654          Casual              Low       Silver    Diamond           1.0
# 101655          Social             High       Silver     Bronze           0.0
# 101656     Competitive              Mid         Gold     Bronze           0.0
# 101657       Collector              Mid         Gold    Diamond           1.0
#
#         null_region
# 0               0.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 101653          0.0
# 101654          0.0
# 101655          0.0
# 101656          0.0
# 101657          1.0
#
# [101658 rows x 12 columns]

# %% [markdown]
# Check if their are still null value remain

# %%
create_null_table(df_cat)
# Out:
# Empty DataFrame
# Columns: [Missing value counts, Missing value percentage]
# Index: []

# %% [markdown]
# Change data into binary

# %%
df_cat_bin = pd.get_dummies(df_cat, drop_first = False)
df_cat_bin.head()
# Out:
#    null_payment  null_region  region_APAC  region_AS  region_EU  region_LATAM  \
# 0           0.0          0.0        False      False      False          True
# 1           0.0          1.0        False      False      False          True
# 2           1.0          1.0        False      False      False          True
# 3           1.0          1.0        False      False      False          True
# 4           0.0          1.0        False      False      False          True
#
#    platform_Console  platform_Mobile  platform_PC  device_type_Desktop  ...  \
# 0             False            False         True                False  ...
# 1              True            False        False                 True  ...
# 2             False            False         True                False  ...
# 3              True            False        False                False  ...
# 4             False            False         True                False  ...
#
#    loyalty_tier_Bronze  loyalty_tier_Diamond  loyalty_tier_Gold  \
# 0                False                 False              False
# 1                False                 False              False
# 2                False                  True              False
# 3                False                 False              False
# 4                False                 False              False
#
#    loyalty_tier_Platinum  loyalty_tier_Silver  skill_tier_Bronze  \
# 0                  False                 True               True
# 1                   True                False              False
# 2                  False                False              False
# 3                  False                 True              False
# 4                  False                 True               True
#
#    skill_tier_Diamond  skill_tier_Gold  skill_tier_Platinum  skill_tier_Silver
# 0               False            False                False              False
# 1               False             True                False              False
# 2               False             True                False              False
# 3               False             True                False              False
# 4               False            False                False              False
#
# [5 rows x 42 columns]

# %% [markdown]
# # Step 2: Training Preparation

# %% [markdown]
# Step 2.1: Merge data

# %%
df_prep = pd.concat([df_num_filled, df_cat_bin], axis = 1)

df_prep.head()
# Out:
#    play_frequency  avg_session_duration  total_playtime_hours  login_streak  \
# 0        5.495437             24.837349           2740.945124     60.000000
# 1        9.991089             88.376322           1643.677401     22.000000
# 2       14.234225            101.712292           2828.479467     66.000000
# 3        3.373683            191.975841           1915.082950     80.000000
# 4       22.469353             28.042509            517.921948     54.708112
#
#    days_since_last_login  total_spending_thb  avg_monthly_spending  \
# 0              56.034052        58219.915660            434.038311
# 1              75.036888        28966.163953           4233.532935
# 2              40.142612        44478.823835           4849.491895
# 3               0.127910        57074.116993           6863.516123
# 4              45.078460        33249.740245           4408.101247
#
#    spending_frequency  friend_count  team_play_percentage  ...  \
# 0           17.790970          58.0             47.791178  ...
# 1           28.862134         276.0             52.789877  ...
# 2           22.536406          71.0             58.267306  ...
# 3           10.565666         105.0             67.274038  ...
# 4           11.226504         111.0             50.677100  ...
#
#    loyalty_tier_Bronze  loyalty_tier_Diamond  loyalty_tier_Gold  \
# 0                False                 False              False
# 1                False                 False              False
# 2                False                  True              False
# 3                False                 False              False
# 4                False                 False              False
#
#    loyalty_tier_Platinum  loyalty_tier_Silver  skill_tier_Bronze  \
# 0                  False                 True               True
# 1                   True                False              False
# 2                  False                False              False
# 3                  False                 True              False
# 4                  False                 True               True
#
#    skill_tier_Diamond  skill_tier_Gold  skill_tier_Platinum  skill_tier_Silver
# 0               False            False                False              False
# 1               False             True                False              False
# 2               False             True                False              False
# 3               False             True                False              False
# 4               False            False                False              False
#
# [5 rows x 77 columns]

# %%
df_prep.isnull().any()
# Out:
# play_frequency           False
# avg_session_duration     False
# total_playtime_hours     False
# login_streak             False
# days_since_last_login    False
#                          ...
# skill_tier_Bronze        False
# skill_tier_Diamond       False
# skill_tier_Gold          False
# skill_tier_Platinum      False
# skill_tier_Silver        False
# Length: 77, dtype: bool

# %% [markdown]
# Step 2.2: Split data

# %%
X = df_prep.drop(columns = 'segment')

X
# Out:
#         play_frequency  avg_session_duration  total_playtime_hours  \
# 0             5.495437             24.837349           2740.945124
# 1             9.991089             88.376322           1643.677401
# 2            14.234225            101.712292           2828.479467
# 3             3.373683            191.975841           1915.082950
# 4            22.469353             28.042509            517.921948
# ...                ...                   ...                   ...
# 101653       17.189970            125.413304           4042.198275
# 101654        7.560260            120.962552           1799.108384
# 101655       11.765396             38.541917           1097.814242
# 101656       12.898003             64.701401           3563.506452
# 101657       15.265967            130.211828            624.018328
#
#         login_streak  days_since_last_login  total_spending_thb  \
# 0          60.000000              56.034052        58219.915660
# 1          22.000000              75.036888        28966.163953
# 2          66.000000              40.142612        44478.823835
# 3          80.000000               0.127910        57074.116993
# 4          54.708112              45.078460        33249.740245
# ...              ...                    ...                 ...
# 101653     47.000000              42.264454        30455.881472
# 101654     20.000000              27.647682        29782.184066
# 101655     25.000000              47.259330        39479.658717
# 101656    120.000000               6.810932        48523.945493
# 101657     58.000000               0.185670        48073.883470
#
#         avg_monthly_spending  spending_frequency  friend_count  \
# 0                 434.038311           17.790970          58.0
# 1                4233.532935           28.862134         276.0
# 2                4849.491895           22.536406          71.0
# 3                6863.516123           10.565666         105.0
# 4                4408.101247           11.226504         111.0
# ...                      ...                 ...           ...
# 101653           5058.189653            9.852469         179.0
# 101654           1516.687257            8.235531          52.0
# 101655           3147.264423            9.703321         149.0
# 101656           1596.091703           31.721567         193.0
# 101657           7415.983681           27.716821          90.0
#
#         team_play_percentage  ...  loyalty_tier_Bronze  loyalty_tier_Diamond  \
# 0                  47.791178  ...                False                 False
# 1                  52.789877  ...                False                 False
# 2                  58.267306  ...                False                  True
# 3                  67.274038  ...                False                 False
# 4                  50.677100  ...                False                 False
# ...                      ...  ...                  ...                   ...
# 101653             11.689707  ...                 True                 False
# 101654              5.000000  ...                False                 False
# 101655             44.062523  ...                False                 False
# 101656             59.351458  ...                False                 False
# 101657             32.047768  ...                False                 False
#
#         loyalty_tier_Gold  loyalty_tier_Platinum  loyalty_tier_Silver  \
# 0                   False                  False                 True
# 1                   False                   True                False
# 2                   False                  False                False
# 3                   False                  False                 True
# 4                   False                  False                 True
# ...                   ...                    ...                  ...
# 101653              False                  False                False
# 101654              False                  False                 True
# 101655              False                  False                 True
# 101656               True                  False                False
# 101657               True                  False                False
#
#         skill_tier_Bronze  skill_tier_Diamond  skill_tier_Gold  \
# 0                    True               False            False
# 1                   False               False             True
# 2                   False               False             True
# 3                   False               False             True
# 4                    True               False            False
# ...                   ...                 ...              ...
# 101653               True               False            False
# 101654              False                True            False
# 101655               True               False            False
# 101656               True               False            False
# 101657              False                True            False
#
#         skill_tier_Platinum  skill_tier_Silver
# 0                     False              False
# 1                     False              False
# 2                     False              False
# 3                     False              False
# 4                     False              False
# ...                     ...                ...
# 101653                False              False
# 101654                False              False
# 101655                False              False
# 101656                False              False
# 101657                False              False
#
# [101658 rows x 76 columns]

# %%
y = df_prep['segment']

y
# Out:
# 0         0.0
# 1         2.0
# 2         3.0
# 3         3.0
# 4         1.0
#          ...
# 101653    1.0
# 101654    0.0
# 101655    2.0
# 101656    3.0
# 101657    3.0
# Name: segment, Length: 101658, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# Check the distribution

# %%
y_train.value_counts() / y_train.shape[0]
# Out:
# segment
# 0.0    0.393281
# 1.0    0.249736
# 2.0    0.201977
# 3.0    0.155006
# Name: count, dtype: float64

# %%
y_test.value_counts() / y_test.shape[0]
# Out:
# segment
# 0.0    0.397403
# 1.0    0.250197
# 2.0    0.202784
# 3.0    0.149616
# Name: count, dtype: float64

# %% [markdown]
# ## Step 3: Modeling

# %%
import xgboost as xgb
learning_rate_range = np.arange(0.01, 1, 0.05)

test_XG = []
train_XG = []

for lr in learning_rate_range:
    xgb_classifier = xgb.XGBClassifier(
                      eta = lr,
                      max_depth = 6,
                      n_estimators = 100,
                      colsample_bytree = 0.8,
                      reg_alpha = 0.1,
                      reg_lambda = 1,
                      scale_pos_weight = 1
                      )
    xgb_classifier.fit(X_train, y_train)
    train_XG.append(xgb_classifier.score(X_train, y_train))
    test_XG.append(xgb_classifier.score(X_test, y_test))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:38:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:38:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:38:37] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:38:50] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:39:03] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:39:16] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:39:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:39:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:39:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:40:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:40:16] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:40:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:40:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:40:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:41:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:41:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:41:30] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:41:43] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:41:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [07:42:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
fig = plt.figure(figsize=(10, 7))
plt.plot(learning_rate_range, train_XG, c='orange', label='Train')
plt.plot(learning_rate_range, test_XG, c='m', label='Test')
plt.xlabel('Learning rate')
plt.xticks(learning_rate_range)
plt.ylabel('Accuracy score')
plt.ylim(0.6, 1)
plt.legend(prop={'size': 12}, loc=3)
plt.title('Accuracy score vs. Learning rate of XGBoost', size=14)
plt.show()

# %% [markdown]
# We can see that the elbow is at 0.1

# %%
xgb_classifier = xgb.XGBClassifier(eta = 0.1)
xgb_classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.1, eval_metric=None,
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None, ...)

# %%
import joblib

joblib.dump(xgb_classifier, 'model.pkl')
# Out:
# ['model.pkl']

# %%
xgb_classifier = joblib.load("model.pkl")

# %%
df_test = pd.read_csv('test.csv')

df_test.isnull().sum()
# Out:
# id                                     0
# player_id                              0
# play_frequency                      2003
# avg_session_duration                1958
# total_playtime_hours                1965
# login_streak                        2014
# days_since_last_login               1896
# total_spending_thb                  1917
# avg_monthly_spending                1931
# spending_frequency                  1950
# friend_count                        2003
# team_play_percentage                2022
# chat_activity_score                 2026
# friend_invites_sent                 2075
# gifts_sent_received                 1917
# ranked_participation_rate           2037
# tournament_entries                  2038
# competitive_rank                    1961
# win_rate_ranked                     2049
# watches_esports                     1996
# achievement_completion_rate         2039
# collection_progress                 1989
# rare_items_count                    2027
# speed_of_progression                1968
# item_type_preference_cosmetic       2078
# item_type_preference_performance    1943
# item_type_preference_social         2011
# account_age_days                    1969
# vip_tier                            2007
# responds_to_discounts               1981
# preferred_game_mode                 2002
# avg_match_length                    1942
# peak_concurrent_hours               2024
# random_metric_1                     1982
# random_metric_2                     2020
# random_metric_3                     1946
# region                              6734
# platform                            1984
# device_type                         1951
# payment_method                      8065
# language                            2007
# account_status                      1928
# player_type_tag                     1988
# engagement_level                    2023
# loyalty_tier                        2064
# skill_tier                          1971
# dtype: int64

# %%
df_test.drop(['id', 'player_id'], axis = 1, inplace = True)

# %%
df_test['null_payment'] = [1.0 if i else 0.0 for i in df_test['payment_method'].isnull()]
df_test['null_region'] = [1.0 if i else 0.0 for i in df_test['region'].isnull()]

# %%
df_test.fillna(df_test.mode(), inplace = True)

df_test
# Out:
#        play_frequency  avg_session_duration  total_playtime_hours  \
# 0            4.917599             50.951821           1610.535142
# 1            8.060471             81.376671            543.088681
# 2            1.004498             27.707037            721.533684
# 3           27.002787             26.859972           1442.810933
# 4            6.188164             49.545383           2039.185739
# ...               ...                   ...                   ...
# 25884        8.775808            136.657801                   NaN
# 25885       14.578502            142.806569           1377.660175
# 25886        7.211300            121.502257           3141.188491
# 25887        2.345938             46.367655           2647.562555
# 25888       15.027342             65.766832           3556.509508
#
#        login_streak  days_since_last_login  total_spending_thb  \
# 0               3.0              40.047516        61031.190124
# 1             104.0              37.296412        10862.656232
# 2              14.0              52.484579        27515.141077
# 3              62.0              43.851594         5299.499711
# 4               8.0              15.519366         7491.446985
# ...             ...                    ...                 ...
# 25884         104.0              27.716894        52024.435292
# 25885         112.0              42.323686        34027.337870
# 25886          43.0              19.584220                 NaN
# 25887          65.0               2.344132        50515.411004
# 25888           7.0               9.901532        75218.955205
#
#        avg_monthly_spending  spending_frequency  friend_count  \
# 0               5403.618682           21.099955         107.0
# 1                100.199386           17.909547           NaN
# 2               1098.230071           26.183854          86.0
# 3                100.574936            3.228531         111.0
# 4               1645.853549           27.231039         148.0
# ...                     ...                 ...           ...
# 25884           6542.959252            8.943746          15.0
# 25885           5003.671636            6.884182         247.0
# 25886                   NaN           31.886739          42.0
# 25887           3160.661119           11.481060           NaN
# 25888           6010.718942           23.580829         158.0
#
#        team_play_percentage  ...  device_type  payment_method  language  \
# 0                 35.339683  ...       Tablet            Gift        EN
# 1                 76.929090  ...       Laptop            Card        ES
# 2                 44.338151  ...        Phone          Wallet        ES
# 3                       NaN  ...        Phone          Wallet        ES
# 4                 57.614515  ...      Desktop          Wallet        ES
# ...                     ...  ...          ...             ...       ...
# 25884             56.538337  ...      Desktop          Wallet        DE
# 25885             32.336687  ...          NaN             NaN        ES
# 25886             51.340148  ...       Tablet             NaN        ES
# 25887             27.986010  ...      Desktop          Wallet        DE
# 25888             55.308130  ...        Phone            Card        FR
#
#        account_status  player_type_tag  engagement_level  loyalty_tier  \
# 0              Active      Competitive               Mid       Diamond
# 1              Active              NaN               Mid        Silver
# 2             Dormant        Collector               Low        Bronze
# 3             Dormant      Competitive               NaN        Bronze
# 4             Dormant      Competitive               Low        Silver
# ...               ...              ...               ...           ...
# 25884          Active      Competitive               Mid        Silver
# 25885             NaN        Collector           Veteran        Silver
# 25886         Dormant        Collector              High           NaN
# 25887         Dormant           Social               Low        Bronze
# 25888         Dormant      Competitive              High          Gold
#
#        skill_tier  null_payment  null_region
# 0            Gold           1.0          1.0
# 1          Bronze           0.0          0.0
# 2        Platinum           0.0          1.0
# 3          Silver           0.0          0.0
# 4        Platinum           0.0          0.0
# ...           ...           ...          ...
# 25884    Platinum           0.0          0.0
# 25885        Gold           1.0          1.0
# 25886        Gold           1.0          1.0
# 25887     Diamond           0.0          1.0
# 25888    Platinum           0.0          0.0
#
# [25889 rows x 46 columns]

# %%
df_cat_bin = pd.get_dummies(df_test, drop_first = False)
df_cat_bin.head()
# Out:
#    play_frequency  avg_session_duration  total_playtime_hours  login_streak  \
# 0        4.917599             50.951821           1610.535142           3.0
# 1        8.060471             81.376671            543.088681         104.0
# 2        1.004498             27.707037            721.533684          14.0
# 3       27.002787             26.859972           1442.810933          62.0
# 4        6.188164             49.545383           2039.185739           8.0
#
#    days_since_last_login  total_spending_thb  avg_monthly_spending  \
# 0              40.047516        61031.190124           5403.618682
# 1              37.296412        10862.656232            100.199386
# 2              52.484579        27515.141077           1098.230071
# 3              43.851594         5299.499711            100.574936
# 4              15.519366         7491.446985           1645.853549
#
#    spending_frequency  friend_count  team_play_percentage  ...  \
# 0           21.099955         107.0             35.339683  ...
# 1           17.909547           NaN             76.929090  ...
# 2           26.183854          86.0             44.338151  ...
# 3            3.228531         111.0                   NaN  ...
# 4           27.231039         148.0             57.614515  ...
#
#    loyalty_tier_Bronze  loyalty_tier_Diamond  loyalty_tier_Gold  \
# 0                False                  True              False
# 1                False                 False              False
# 2                 True                 False              False
# 3                 True                 False              False
# 4                False                 False              False
#
#    loyalty_tier_Platinum  loyalty_tier_Silver  skill_tier_Bronze  \
# 0                  False                False              False
# 1                  False                 True               True
# 2                  False                False              False
# 3                  False                False              False
# 4                  False                 True              False
#
#    skill_tier_Diamond  skill_tier_Gold  skill_tier_Platinum  skill_tier_Silver
# 0               False             True                False              False
# 1               False            False                False              False
# 2               False            False                 True              False
# 3               False            False                False               True
# 4               False            False                 True              False
#
# [5 rows x 76 columns]

# %%
y_pred = xgb_classifier.predict(df_cat_bin)

y_pred
# Out:
# array([2, 0, 0, ..., 3, 0, 3])

# %%
save_y = pd.DataFrame(y_pred)

save_y.to_csv("predicted.csv")
